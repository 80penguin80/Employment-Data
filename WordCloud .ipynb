# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df= pd.read_excel('/Users/Owner/OneDrive/Desktop/nflx.xls')

# %%
a=list(df['CONs'])
b=list(df['PROs'])

aa=''
bb=''
text_cons = aa.join(a)
text_pros = bb.join(b)

# %%
netflix_cons=WordCloud().generate(text_cons)
netflix_pros=WordCloud().generate(text_pros)

# %%
plt.figure(figsize=(25,20))
plt.imshow(netflix_cons, interpolation='bilinear')

# %%
plt.figure(figsize=(25,20))
plt.imshow(netflix_pros, interpolation='bilinear')

# %%
summary=list(df['Summary'])
summary[0]
# Out:
# 'I loved working on the show'

# %%
sentiment=[]

for i in df['CONs']:
    if i.__contains__('toxic'):
        sentiment.append(1)
sentiment
# Out:
# [1, 1, 1, 1, 1, 1, 1]

# %%
positive=['love', 'great', 'good', 'amazing', 'fantastic', 'enjoyed', 'enjoy', 'like', 'liked']
j=0
for i in summary:
        if i.__contains__[positive[j]]:
            s.append(1)
        j=j+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-416dafc0650d> in <module>
#       2 j=0
#       3 for i in summary:
# ----> 4         if i.__contains__[positive[j]]:
#       5             s.append(1)
#       6         j=j+1
#
# TypeError: 'method-wrapper' object is not subscriptable

# %%
positive[j]
# Out:
# 'love'

# %%
for i in summary:
        for a in positive:
            if i.__contains__[a]:
                s.append(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-7c66f6aff983> in <module>
#       1 for i in summary:
#       2         for a in positive:
# ----> 3             if i.__contains__[a]:
#       4                 s.append(1)
#
# TypeError: 'method-wrapper' object is not subscriptable

# %%
i.__contains__(positive[0])
# Out:
# True
