# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import plotly.offline as py
py.init_notebook_mode(connected=True)
import pandas as pd
from wordcloud import WordCloud

df= pd.read_excel('/Users/Owner/OneDrive/Desktop/Coin.xlsx')
df
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#       Ticker Symbol  Entity Name  CUSIP  ISIN  Unique ID  As Of Date  \
# 0       nasdaq:coin    886427730    NaN   NaN    2062943    20211101
# 1       nasdaq:coin    886427730    NaN   NaN    2062934    20211101
# 2       nasdaq:coin    886427730    NaN   NaN    2047139    20211101
# 3       nasdaq:coin    886427730    NaN   NaN    2043413    20211101
# 4       nasdaq:coin    886427730    NaN   NaN    2045841    20211101
# ...             ...          ...    ...   ...        ...         ...
# 27773   nasdaq:coin    886427730    NaN   NaN    2061036    20140620
# 27774   nasdaq:coin    886427730    NaN   NaN    2057059    20140620
# 27775   nasdaq:coin    886427730    NaN   NaN    2059174    20140620
# 27776   nasdaq:coin    886427730    NaN   NaN    2060069    20140620
# 27777   nasdaq:coin    886427730    NaN   NaN    2061251    20140619
#
#                                                      URL  Rating  \
# 0      https://apps.apple.com/us/app/slug/id886427730...       1
# 1      https://apps.apple.com/us/app/slug/id886427730...       1
# 2      https://apps.apple.com/us/app/slug/id886427730...       5
# 3      https://apps.apple.com/us/app/slug/id886427730...       1
# 4      https://apps.apple.com/us/app/slug/id886427730...       5
# ...                                                  ...     ...
# 27773  https://apps.apple.com/us/app/slug/id886427730...       2
# 27774  https://apps.apple.com/us/app/slug/id886427730...       5
# 27775  https://apps.apple.com/us/app/slug/id886427730...       5
# 27776  https://apps.apple.com/us/app/slug/id886427730...       1
# 27777  https://apps.apple.com/us/app/slug/id886427730...       1
#
#                                                   Review  \
# 0      I never write reviews... My id verify has beg ...
# 1      Can’t even verify my identity to open an accou...
# 2      I’m new to te\nHe crypto game but this app off...
# 3      I’ve submitted so many request just for each o...
# 4      So much helpful information! Taught me a lot i...
# ...                                                  ...
# 27773       can't buy or sell bitcoin, what's the point.
# 27774  This is what I've been waiting for.  I was ser...
# 27775  Send, receive, scan QR codes and monitor your ...
# 27776  This is not made by Coinbase.   If you used th...
# 27777     To many timed steps. Authy, emails and Safari.
#
#                                                Title  ...  \
# 0                                        ID VERIFY?!  ...
# 1                          Terrible customer service  ...
# 2                                         Great app!  ...
# 3                        Worst Customer Service Ever  ...
# 4                                Best Investing App!  ...
# ...                                              ...  ...
# 27773                                 coinbase lite?  ...
# 27774  Thank GOD! Now I don't have to go to Andriod!  ...
# 27775                                       Awesome!  ...
# 27776                                   WARNING FAKE  ...
# 27777                     Setup basically impossible  ...
#
#                                   App  \
# 0      Coinbase: Trade BTC, ETH, SHIB
# 1      Coinbase: Trade BTC, ETH, SHIB
# 2      Coinbase: Trade BTC, ETH, SHIB
# 3      Coinbase: Trade BTC, ETH, SHIB
# 4      Coinbase: Trade BTC, ETH, SHIB
# ...                               ...
# 27773  Coinbase: Trade BTC, ETH, SHIB
# 27774  Coinbase: Trade BTC, ETH, SHIB
# 27775  Coinbase: Trade BTC, ETH, SHIB
# 27776  Coinbase: Trade BTC, ETH, SHIB
# 27777  Coinbase: Trade BTC, ETH, SHIB
#
#                                              App Link        Date Added  \
# 0      https://apps.apple.com/us/app/slug/id886427730  20211102T223109Z
# 1      https://apps.apple.com/us/app/slug/id886427730  20211102T223109Z
# 2      https://apps.apple.com/us/app/slug/id886427730  20211102T221857Z
# 3      https://apps.apple.com/us/app/slug/id886427730  20211102T221615Z
# 4      https://apps.apple.com/us/app/slug/id886427730  20211102T221810Z
# ...                                               ...               ...
# 27773  https://apps.apple.com/us/app/slug/id886427730  20211102T222946Z
# 27774  https://apps.apple.com/us/app/slug/id886427730  20211102T222634Z
# 27775  https://apps.apple.com/us/app/slug/id886427730  20211102T222811Z
# 27776  https://apps.apple.com/us/app/slug/id886427730  20211102T222858Z
# 27777  https://apps.apple.com/us/app/slug/id886427730  20211102T222946Z
#
#            Date Updated      Sector           Industry GICS Sector  \
# 0      20211102T223109Z  Technology  General Financial   Financial
# 1      20211102T223109Z  Technology  General Financial   Financial
# 2      20211102T221857Z  Technology  General Financial   Financial
# 3      20211102T221615Z  Technology  General Financial   Financial
# 4      20211102T221810Z  Technology  General Financial   Financial
# ...                 ...         ...                ...         ...
# 27773  20211102T222946Z  Technology  General Financial   Financial
# 27774  20211102T222634Z  Technology  General Financial   Financial
# 27775  20211102T222811Z  Technology  General Financial   Financial
# 27776  20211102T222858Z  Technology  General Financial   Financial
# 27777  20211102T222946Z  Technology  General Financial   Financial
#
#          GICS Industry ICB Industry ICB Sector
# 0      Capital Markets   Technology        NaN
# 1      Capital Markets   Technology        NaN
# 2      Capital Markets   Technology        NaN
# 3      Capital Markets   Technology        NaN
# 4      Capital Markets   Technology        NaN
# ...                ...          ...        ...
# 27773  Capital Markets   Technology        NaN
# 27774  Capital Markets   Technology        NaN
# 27775  Capital Markets   Technology        NaN
# 27776  Capital Markets   Technology        NaN
# 27777  Capital Markets   Technology        NaN
#
# [27778 rows x 25 columns]

# %%
#rating distribution
rating=df['Rating']
plt.hist(rating, bins=5)
# Out:
# (array([10521.,  2003.,  2308.,  2410., 10536.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. ]),
#  <BarContainer object of 5 artists>)

# %%
df.groupby('Rating')['URL'].count()
# Out:
# Rating
# 1    10521
# 2     2003
# 3     2308
# 4     2410
# 5    10536
# Name: URL, dtype: int64

# %%
#average rating
mean=rating.mean()
mean
# Out:
# 3.0157318741450068

# %%
#wordcloud of all reviews
a=list(df['Review'])

aa=''

text_reviews = aa.join(a)
coinbase_reviews=WordCloud().generate(text_reviews)

plt.figure(figsize=(25,20))
plt.imshow(coinbase_reviews, interpolation='bilinear')

# %%
# assign reviews with score > 3 as positive sentiment
# score < 3 negative sentiment
# remove score = 3
df = df[df['Rating'] != 3]
df['sentiment'] = df['Rating'].apply(lambda rating : +1 if rating > 3 else -1)
df['sentiment'].mean() #review sentiments score
# Out:
# <ipython-input-9-072811ca8dfb>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0.0165685119748724

# %%
# split df - positive and negative sentiment:
positive = df[df['sentiment'] == 1]
negative = df[df['sentiment'] == -1]

positive_reviews=positive['Review']
negative_reviews=negative['Review']

#positive review wordcloud
p=list(positive['Review'])

pp=''

pos = pp.join(p)
pos_reviews=WordCloud().generate(pos)

plt.figure(figsize=(25,20))
plt.imshow(pos_reviews, interpolation='bilinear')

# %%
#negative review wordcloud
n=list(negative['Review'])

nn=''

neg = nn.join(n)
neg_reviews=WordCloud().generate(neg)

plt.figure(figsize=(25,20))
plt.imshow(neg_reviews, interpolation='bilinear')

# %%
#distribution of sentiment
sentiment_ratings=df['sentiment']

plt.hist(sentiment_ratings)
# Out:
# (array([12524.,     0.,     0.,     0.,     0.,     0.,     0.,     0.,
#             0., 12946.]),
#  array([-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  <BarContainer object of 10 artists>)

# %%
#review sentiment
sentiment_ratings.mean()
# Out:
# 0.0165685119748724

# %%
def remove_punctuation(text):
    final = "".join(u for u in text if u not in ("?", ".", ";", ":",  "!",'"'))
    return final
df['Review'] = df['Review'].apply(remove_punctuation)
df = df.dropna(subset=['Title'])
df['Title'] = df['Title'].apply(remove_punctuation)
df['Title']
# Out:
# <ipython-input-18-6c70fdbfcf4a>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0                                          ID VERIFY
# 1                          Terrible customer service
# 2                                          Great app
# 3                        Worst Customer Service Ever
# 4                                 Best Investing App
#                             ...
# 27773                                  coinbase lite
# 27774    Thank GOD Now I don't have to go to Andriod
# 27775                                        Awesome
# 27776                                   WARNING FAKE
# 27777                     Setup basically impossible
# Name: Title, Length: 25469, dtype: object

# %%
dfNew = df[['Title','sentiment']]
dfNew.head()
# Out:
#                          Title  sentiment
# 0                    ID VERIFY         -1
# 1    Terrible customer service         -1
# 2                    Great app          1
# 3  Worst Customer Service Ever         -1
# 4           Best Investing App          1

# %%
# random split train and test data
index = df.index
df['random_number'] = np.random.randn(len(index))
train = df[df['random_number'] <= 0.8]
test = df[df['random_number'] > 0.8]

# %%
# count vectorizer:
#from sklearn.feature_extraction.text import CountVectorizer
#vectorizer = CountVectorizer(token_pattern=r'\b\w+\b')
#train_matrix = vectorizer.fit_transform(train['Title'])
#test_matrix = vectorizer.transform(test['Title'])

# %%
#work in progress
#review=df[df['Review'].str.contains('bad')]
#review=review.groupby('As Of Date')['URL'].count()
#dates=review.index

#plt.plot(dates, review)

# %%
#work in progress
#sentiment=[]
#reviews=df[df['Review']]
#for i in reviews:
#    if .__contains__('bad'):
#        sentiment.append(-1)
#    elif i.str.contains('good'):
#        sentiment.append(1)
#sentiment.mean()
